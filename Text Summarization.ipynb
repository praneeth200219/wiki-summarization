# %%
import bs4 as bs
import urllib.request
import re
import nltk
import heapq
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords

# %%
# Read the data from the web
scraped_data = urllib.request.urlopen('https://en.wikipedia.org/wiki/Artificial_intelligence')
article = scraped_data.read()
parsed_article = bs.BeautifulSoup(article,'lxml')

#Convert the data into string
paragraphs = parsed_article.find_all('p')
article_text = ""
for p in paragraphs:
    article_text += p.text

# %% [markdown]
# ### Cleaning of the data

# %%
def clean_text(raw_text):
    """
    Input: Raw Paragraph/Sentences/Text
    Output: Paragraph which doesn't contain references, special characters, digits and extra spaces
    
    """

    # Removing Square Brackets and Extra Spaces
    raw_text = re.sub(r'\[[0-9]*\]', ' ', raw_text)
    raw_text = re.sub(r'\s+', ' ', raw_text)

    # Removing special characters and digits
    formatted_article_text = re.sub('[^a-zA-Z]', ' ', raw_text )
    formatted_article_text = re.sub(r'\s+', ' ', formatted_article_text)
    
    return formatted_article_text

# %%
# Checking our function
cleaned_text = clean_text(article_text)
cleaned_text
# Out:
# ' Artificial intelligence AI is intelligence demonstrated by machines unlike the natural intelligence displayed by humans and animals Leading AI textbooks define the field as the study of intelligent agents any device that perceives its environment and takes actions that maximize its chance of successfully achieving its goals Colloquially the term artificial intelligence is often used to describe machines or computers that mimic cognitive functions that humans associate with the human mind such as learning and problem solving As machines become increasingly capable tasks considered to require intelligence are often removed from the definition of AI a phenomenon known as the AI effect A quip in Tesler s Theorem says AI is whatever hasn t been done yet For instance optical character recognition is frequently excluded from things considered to be AI having become a routine technology Modern machine capabilities generally classified as AI include successfully understanding human speech competing at the highest level in strategic game systems such as chess and Go autonomously operating cars intelligent routing in content delivery networks and military simulations Artificial intelligence was founded as an academic discipline in and in the years since has experienced several waves of optimism followed by disappointment and the loss of funding known as an AI winter followed by new approaches success and renewed funding After AlphaGo successfully defeated a professional Go player in artificial intelligence once again attracted widespread global attention For most of its history AI research has been divided into sub fields that often fail to communicate with each other These sub fields are based on technical considerations such as particular goals e g robotics or machine learning the use of particular tools logic or artificial neural networks or deep philosophical differences Sub fields have also been based on social factors particular institutions or the work of particular researchers The traditional problems or goals of AI research include reasoning knowledge representation planning learning natural language processing perception and the ability to move and manipulate objects General intelligence is among the field s long term goals Approaches include statistical methods computational intelligence and traditional symbolic AI Many tools are used in AI including versions of search and mathematical optimization artificial neural networks and methods based on statistics probability and economics The AI field draws upon computer science information engineering mathematics psychology linguistics philosophy and many other fields The field was founded on the assumption that human intelligence can be so precisely described that a machine can be made to simulate it This raises philosophical arguments about the mind and the ethics of creating artificial beings endowed with human like intelligence These issues have been explored by myth fiction and philosophy since antiquity Some people also consider AI to be a danger to humanity if it progresses unabated Others believe that AI unlike previous technological revolutions will create a risk of mass unemployment In the twenty first century AI techniques have experienced a resurgence following concurrent advances in computer power large amounts of data and theoretical understanding and AI techniques have become an essential part of the technology industry helping to solve many challenging problems in computer science software engineering and operations research Thought capable artificial beings appeared as storytelling devices in antiquity and have been common in fiction as in Mary Shelley s Frankenstein or Karel apek s R U R These characters and their fates raised many of the same issues now discussed in the ethics of artificial intelligence The study of mechanical or formal reasoning began with philosophers and mathematicians in antiquity The study of mathematical logic led directly to Alan Turing s ...

# %% [markdown]
# ### Sentence Tokenization

# %%
sentence_list = nltk.sent_tokenize(article_text)

# %%
sentence_list[:5]
# Out:
# ['\n\nArtificial intelligence (AI), is intelligence demonstrated by machines, unlike the natural intelligence displayed by humans and animals.',
#  'Leading AI textbooks define the field as the study of "intelligent agents": any device that perceives its environment and takes actions that maximize its chance of successfully achieving its goals.',
#  '[3] Colloquially, the term "artificial intelligence" is often used to describe machines (or computers) that mimic "cognitive" functions that humans associate with the human mind, such as "learning" and "problem solving".',
#  '[4]\nAs machines become increasingly capable, tasks considered to require "intelligence" are often removed from the definition of AI, a phenomenon known as the AI effect.',
#  '[5] A quip in Tesler\'s Theorem says "AI is whatever hasn\'t been done yet.']

# %% [markdown]
# ### Word Frequency Count

# %%
def word_freq_count(text):
    stopwords = nltk.corpus.stopwords.words('english')

    word_frequencies = {}
    for word in nltk.word_tokenize(text):
        if word not in stopwords:
            if word not in word_frequencies.keys():
                word_frequencies[word] = 1
            else:
                word_frequencies[word] += 1
    
    return word_frequencies

# %%
# Displaying of all the word Frequencies
word_freq_count(formatted_article_text)
# Out:
# {'Artificial': 7,
#  'intelligence': 73,
#  'AI': 143,
#  'demonstrated': 1,
#  'machines': 23,
#  'unlike': 5,
#  'natural': 10,
#  'displayed': 2,
#  'humans': 25,
#  'animals': 2,
#  'Leading': 2,
#  'textbooks': 1,
#  'define': 1,
#  'field': 17,
#  'study': 6,
#  'intelligent': 17,
#  'agents': 8,
#  'device': 2,
#  'perceives': 2,
#  'environment': 6,
#  'takes': 3,
#  'actions': 9,
#  'maximize': 4,
#  'chance': 4,
#  'successfully': 6,
#  'achieving': 3,
#  'goals': 14,
#  'Colloquially': 1,
#  'term': 7,
#  'artificial': 51,
#  'often': 14,
#  'used': 15,
#  'describe': 3,
#  'computers': 10,
#  'mimic': 3,
#  'cognitive': 5,
#  'functions': 2,
#  'associate': 1,
#  'human': 57,
#  'mind': 18,
#  'learning': 28,
#  'problem': 20,
#  'solving': 8,
#  'As': 2,
#  'become': 7,
#  'increasingly': 2,
#  'capable': 8,
#  'tasks': 5,
#  'considered': 9,
#  'require': 4,
#  'removed': 1,
#  'definition': 3,
#  'phenomenon': 3,
#  'known': 8,
#  'effect': 3,
#  'A': 29,
#  'quip': 1,
#  'Tesler': 1,
#  'Theorem': 1,
#  'says': 1,
#  'whatever': 1,
#  'done': 1,
#  'yet': 1,
#  'For': 10,
#  'instance': 2,
#  'optical': 1,
#  'character': 2,
#  'recognition': 6,
#  'frequently': 1,
#  'excluded': 1,
#  'things': 6,
#  'routine': 3,
#  'technology': 15,
#  'Modern': 3,
#  'machine': 24,
#  'capabilities': 4,
#  'generally': 7,
#  'classified': 1,
#  'include': 10,
#  'understanding': 11,
#  'speech': 2,
#  'competing': 2,
#  'highest': 1,
#  'level': 9,
#  'strategic': 1,
#  'game': 5,
#  'systems': 21,
#  'chess': 3,
#  'Go': 10,
#  'autonomously': 1,
#  'operating': 2,
#  'cars': 4,
#  'routing': 1,
#  'content': 3,
#  'delivery': 1,
#  'networks': 10,
#  'military': 1,
#  'simulations': 1,
#  'founded': 2,
#  'academic': 3,
#  'discipline': 2,
#  'years': 6,
#  'since': 7,
#  'experienced': 3,
#  'several': 3,
#  'waves': 2,
#  'optimism': 1,
#  'followed': 3,
#  'disappointment': 1,
#  'loss': 1,
#  'funding': 5,
#  'winter': 2,
#  'new': 8,
#  'approaches': 14,
#  'success': 5,
#  'renewed': 1,
#  'After': 2,
#  'AlphaGo': 3,
#  'defeated': 2,
#  'professional': 2,
#  'player': 3,
#  'attracted': 1,
#  'widespread': 1,
#  'global': 1,
#  'attention': 2,
#  'history': 2,
#  'research': 37,
#  'divided': 1,
#  'sub': 4,
#  'fields': 7,
#  'fail': 1,
#  'communicate': 1,
#  'These': 9,
#  'based': 9,
#  'technical': 1,
#  'considerations': 1,
#  'particular': 8,
#  'e': 4,
#  'g': 4,
#  'robotics': 7,
#  'use': 23,
#  'tools': 5,
#  'logic': 11,
#  'neural': 10,
#  'deep': 3,
#  'philosophical': 6,
#  'differences': 1,
#  'Sub': 2,
#  'also': 28,
#  'social': 9,
#  'factors': 2,
#  'institutions': 2,
#  'work': 11,
#  'researchers': 16,
#  'The': 56,
#  'traditional': 3,
#  'problems': 23,
#  'reasoning': 13,
#  'knowledge': 30,
#  'representation': 6,
#  'planning': 5,
#  'language': 12,
#  'processing': 10,
#  'perception': 6,
#  'ability': 9,
#  'move': 3,
#  'manipulate': 1,
#  'objects': 5,
#  'General': 1,
#  'among': 3,
#  'long': 6,
#  'Approaches': 2,
#  'statistical': 7,
#  'methods': 7,
#  'computational': 6,
#  'symbolic': 12,
#  'Many': 9,
#  'including': 9,
#  'versions': 1,
#  'search': 5,
#  'mathematical': 8,
#  'optimization': 3,
#  'statistics': 2,
#  'probability': 3,
#  'economics': 4,
#  'draws': 1,
#  'upon': 3,
#  'computer': 18,
#  'science': 9,
#  'information': 8,
#  'engineering': 5,
#  'mathematics': 3,
#  'psychology': 3,
#  'linguistics': 1,
#  'philosophy': 3,
#  'many': 21,
#  'assumption': 1,
#  'precisely': 1,
#  'described': 10,
#  'made': 1,
#  'simulate': 7,
#  'This': 19,
#  'raises': 1,
#  'arguments': 1,
#  'ethics': 13,
#  'creating': 5,
#  'beings': 8,
#  'endowed': 1,
#  'like': 14,
#  'issues': 5,
#  'explored': 3,
#  'myth': 1,
#  'fiction': 6,
#  'antiquity': 4,
#  'Some': 12,
#  'people': 13,
#  'consider': 5,
#  'danger': 2,
#  'humanity': 6,
#  'progresses': 1,
#  'unabated': 1,
#  'Others': 1,
#  'believe': 8,
#  'previous': 2,
#  'technological': 2,
#  'revolutions': 1,
#  'create': 3,
#  'risk': 10,
#  'mass': 1,
#  'unemployment': 2,
#  'In': 22,
#  'twenty': 2,
#  'first': 11,
#  'century': 2,
#  'techniques': 6,
#  'resurgence': 1,
#  'following': 2,
#  'concurrent': 2,
#  'advances': 4,
#  'power': 5,
#  'large': 10,
#  'amounts': 3,
#  'data': 22,
#  'theoretical': 1,
#  'essential': 1,
#  'part': 3,
#  'industry': 2,
#  'helping': 1,
#  'solve': 8,
#  'challenging': 2,
#  'software': 9,
#  'operations': 4,
#  'Thought': 2,
#  'appeared': 2,
#  'storytelling': 2,
#  'devices': 2,
#  'common': 3,
#  'Mary': 2,
#  'Shelley': 2,
#  'Frankenstein': 2,
#  'Karel': 2,
#  'apek': 2,
#  'R': 4,
#  'U': 8,
#  'characters': 1,
#  'fates': 1,
#  'raised': 1,
#  'discussed': 3,
#  'mechanical': 2,
#  'formal': 6,
#  'began': 7,
#  'philosophers': 3,
#  'mathematicians': 1,
#  'led': 6,
#  'directly': 2,
#  'Alan': 1,
#  'Turing': 4,
#  'theory': 16,
#  'computation': 3,
#  'suggested': 1,
#  'shuffling': 1,
#  'symbols': 1,
#  'simple': 6,
#  'could': 24,
#  'conceivable': 1,
#  'act': 1,
#  'deduction': 2,
#  'insight': 1,
#  'digital': 4,
#  'process': 4,
#  'Church': 1,
#  'thesis': 2,
#  'Along': 1,
#  'discoveries': 1,
#  'neurobiology': 3,
#  'cybernetics': 5,
#  'possibility': 5,
#  'building': 3,
#  'electronic': 2,
#  'brain': 8,
#  'proposed': 4,
#  'changing': 2,
#  'question': 7,
#  'whether': 7,
#  'possible': 10,
#  'machinery': 3,
#  'show': 2,
#  'behaviour': 1,
#  'recognized': 1,
#  'McCullouch': 1,
#  'Pitts': 1,
#  'design': 1,
#  'complete': 3,
#  'neurons': 3,
#  'born': 2,
#  'workshop': 1,
#  'Dartmouth': 1,
#  'College': 1,
#  'Intelligence': 4,
#  'coined': 1,
#  'John': 5,
#  'McCarthy': 3,
#  'distinguish': 1,
#  'escape': 2,
#  'influence': 1,
#  'cyberneticist': 2,
#  'Norbert': 1,
#  'Wiener': 1,
#  'Attendees': 1,
#  'Allen': 2,
#  'Newell': 3,
#  'CMU': 3,
#  'Herbert': 3,
#  'Simon': 4,
#  'MIT': 4,
#  'Marvin': 3,
#  'Minsky': 3,
#  'Arthur': 2,
#  'Samuel': 2,
#  'IBM': 2,
#  'became': 5,
#  'founders': 2,
#  'leaders': 2,
#  'They': 5,
#  'students': 1,
#  'produced': 2,
#  'programs': 4,
#  'press': 1,
#  'astonishing': 1,
#  'checkers': 3,
#  'strategies': 6,
#  'c': 3,
#  'reportedly': 1,
#  'playing': 5,
#  'better': 7,
#  'average': 5,
#  'word': 4,
#  'algebra': 1,
#  'proving': 2,
#  'logical': 4,
#  'theorems': 2,
#  'Logic': 3,
#  'Theorist': 1,
#  'run': 2,
#  'speaking': 1,
#  'English': 1,
#  'By': 6,
#  'middle': 4,
#  'S': 6,
#  'heavily': 2,
#  'funded': 1,
#  'Department': 1,
#  'Defense': 1,
#  'laboratories': 1,
#  'established': 3,
#  'around': 6,
#  'world': 12,
#  'optimistic': 1,
#  'future': 5,
#  'predicted': 2,
#  'within': 4,
#  'man': 1,
#  'agreed': 1,
#  'writing': 1,
#  'generation': 2,
#  'substantially': 2,
#  'solved': 3,
#  'failed': 3,
#  'recognize': 2,
#  'difficulty': 5,
#  'remaining': 1,
#  'Progress': 1,
#  'slowed': 1,
#  'response': 1,
#  'criticism': 1,
#  'Sir': 1,
#  'James': 1,
#  'Lighthill': 1,
#  'ongoing': 1,
#  'pressure': 1,
#  'US': 1,
#  'Congress': 1,
#  'fund': 2,
#  'productive': 1,
#  'projects': 7,
#  'British': 2,
#  'governments': 2,
#  'cut': 1,
#  'exploratory': 1,
#  'next': 4,
#  'would': 28,
#  'later': 3,
#  'called': 3,
#  'period': 1,
#  'obtaining': 1,
#  'difficult': 10,
#  'early': 5,
#  'revived': 4,
#  'commercial': 2,
#  'expert': 4,
#  'form': 9,
#  'program': 5,
#  'simulated': 3,
#  'analytical': 1,
#  'skills': 7,
#  'experts': 4,
#  'market': 2,
#  'reached': 1,
#  'billion': 2,
#  'dollars': 1,
#  'At': 1,
#  'time': 8,
#  'Japan': 2,
#  'fifth': 1,
#  'project': 1,
#  'inspired': 3,
#  'restore': 1,
#  'However': 4,
#  'beginning': 1,
#  'collapse': 1,
#  'Lisp': 1,
#  'Machine': 7,
#  'fell': 1,
#  'disrepute': 1,
#  'second': 2,
#  'longer': 2,
#  'lasting': 1,
#  'hiatus': 1,
#  'development': 14,
#  'metal': 1,
#  'oxide': 1,
#  'semiconductor': 1,
#  'MOS': 2,
#  'scale': 1,
#  'integration': 1,
#  'VLSI': 2,
#  'complementary': 1,
#  'CMOS': 1,
#  'transistor': 2,
#  'enabled': 2,
#  'practical': 2,
#  'network': 2,
#  'ANN': 1,
#  'landmark': 2,
#  'publication': 1,
#  'book': 6,
#  'Analog': 1,
#  'Implementation': 1,
#  'Neural': 1,
#  'Systems': 2,
#  'Carver': 1,
#  'Mead': 1,
#  'Mohammed': 1,
#  'Ismail': 1,
#  'late': 2,
#  'st': 1,
#  'logistics': 1,
#  'mining': 4,
#  'medical': 3,
#  'diagnosis': 4,
#  'areas': 4,
#  'due': 2,
#  'increasing': 7,
#  'see': 4,
#  'Moore': 2,
#  'law': 2,
#  'count': 1,
#  'greater': 2,
#  'emphasis': 2,
#  'specific': 6,
#  'ties': 1,
#  'commitment': 1,
#  'scientific': 2,
#  'standards': 1,
#  'Deep': 1,
#  'Blue': 1,
#  'system': 20,
#  'beat': 2,
#  'reigning': 1,
#  'champion': 2,
#  'Garry': 1,
#  'Kasparov': 1,
#  'May': 1,
#  'Jeopardy': 2,
#  'quiz': 1,
#  'exhibition': 1,
#  'match': 5,
#  'answering': 2,
#  'Watson': 1,
#  'two': 6,
#  'greatest': 1,
#  'champions': 1,
#  'Brad': 1,
#  'Rutter': 1,
#  'Ken': 1,
#  'Jennings': 1,
#  'significant': 2,
#  'margin': 1,
#  'Faster': 1,
#  'algorithmic': 2,
#  'improvements': 2,
#  'access': 2,
#  'hungry': 1,
#  'started': 1,
#  'dominate': 1,
#  'accuracy': 3,
#  'benchmarks': 1,
#  'Kinect': 1,
#  'provides': 2,
#  'D': 1,
#  'body': 5,
#  'motion': 2,
#  'interface': 1,
#  'Xbox': 2,
#  'One': 4,
#  'uses': 5,
#  'algorithms': 14,
#  'emerged': 1,
#  'lengthy': 1,
#  'personal': 2,
#  'assistants': 3,
#  'smartphones': 1,
#  'March': 1,
#  'games': 3,
#  'Lee': 1,
#  'Sedol': 1,
#  'becoming': 4,
#  'without': 6,
#  'handicaps': 1,
#  'Future': 4,
#  'Summit': 1,
#  'three': 4,
#  'Ke': 1,
#  'Jie': 1,
#  'continuously': 1,
#  'held': 1,
#  'No': 2,
#  'ranking': 1,
#  'marked': 1,
#  'completion': 1,
#  'milestone': 1,
#  'relatively': 1,
#  'complex': 7,
#  'Chess': 2,
#  'According': 1,
#  'Bloomberg': 1,
#  'Jack': 1,
#  'Clark': 2,
#  'year': 4,
#  'number': 5,
#  'Google': 2,
#  'increased': 2,
#  'sporadic': 1,
#  'usage': 1,
#  'presents': 2,
#  'factual': 1,
#  'indicating': 1,
#  'supported': 1,
#  'lower': 1,
#  'error': 2,
#  'rates': 1,
#  'image': 5,
#  'He': 4,
#  'attributes': 1,
#  'increase': 6,
#  'affordable': 1,
#  'rise': 3,
#  'cloud': 1,
#  'computing': 7,
#  'infrastructure': 1,
#  'datasets': 2,
#  'Other': 4,
#  'cited': 1,
#  'examples': 3,
#  'Microsoft': 2,
#  'Skype': 1,
#  'automatically': 2,
#  'translate': 1,
#  'one': 9,
#  'another': 1,
#  'Facebook': 2,
#  'images': 3,
#  'blind': 2,
#  'survey': 2,
#  'five': 1,
#  'companies': 2,
#  'reported': 1,
#  'incorporated': 2,
#  'offerings': 1,
#  'processes': 4,
#  'Around': 1,
#  'China': 3,
#  'greatly': 2,
#  'accelerated': 1,
#  'government': 1,
#  'given': 5,
#  'supply': 1,
#  'rapidly': 1,
#  'output': 2,
#  'observers': 1,
#  'may': 18,
#  'track': 1,
#  'superpower': 1,
#  'acknowledged': 1,
#  'reports': 2,
#  'regarding': 1,
#  'tended': 2,
#  'exaggerated': 1,
#  'Computer': 4,
#  'defines': 1,
#  'elaborate': 1,
#  'characterizes': 1,
#  'correctly': 1,
#  'interpret': 4,
#  'external': 1,
#  'learn': 8,
#  'learnings': 1,
#  'achieve': 6,
#  'flexible': 1,
#  'adaptation': 2,
#  'typical': 1,
#  'analyzes': 1,
#  'An': 3,
#  'intended': 1,
#  'utility': 2,
#  'function': 10,
#  'goal': 12,
#  'wins': 1,
#  'otherwise': 5,
#  'Perform': 1,
#  'mathematically': 2,
#  'similar': 3,
#  'ones': 4,
#  'succeeded': 1,
#  'past': 6,
#  'Goals': 1,
#  'explicitly': 2,
#  'defined': 1,
#  'induced': 2,
#  'If': 11,
#  'programmed': 3,
#  'reinforcement': 3,
#  'implicitly': 2,
#  'rewarding': 2,
#  'types': 2,
#  'behavior': 10,
#  'punishing': 1,
#  'others': 6,
#  'Alternatively': 1,
#  'evolutionary': 4,
#  'induce': 1,
#  'using': 8,
#  'fitness': 1,
#  'mutate': 1,
#  'preferentially': 1,
#  'replicate': 1,
#  'high': 7,
#  'scoring': 1,
#  'evolved': 2,
#  'innately': 1,
#  'desire': 1,
#  'certain': 3,
#  'finding': 1,
#  'food': 2,
#  'nearest': 3,
#  'neighbor': 3,
#  'instead': 4,
#  'reason': 6,
#  'analogy': 1,
#  'except': 2,
#  'degree': 2,
#  'implicit': 2,
#  'training': 2,
#  'Such': 4,
#  'still': 3,
#  'benchmarked': 1,
#  'non': 5,
#  'framed': 1,
#  'whose': 2,
#  'accomplish': 1,
#  'narrow': 5,
#  'classification': 2,
#  'task': 3,
#  'revolves': 1,
#  'algorithm': 4,
#  'set': 3,
#  'unambiguous': 1,
#  'instructions': 1,
#  'execute': 1,
#  'b': 1,
#  'built': 3,
#  'top': 1,
#  'simpler': 2,
#  'example': 19,
#  'optimal': 1,
#  'recipe': 1,
#  'play': 1,
#  'tic': 1,
#  'tac': 1,
#  'toe': 1,
#  'enhance': 1,
#  'heuristics': 1,
#  'rules': 2,
#  'thumb': 1,
#  'worked': 3,
#  'well': 13,
#  'write': 2,
#  'learners': 5,
#  'Bayesian': 3,
#  'decision': 6,
#  'trees': 1,
#  'theoretically': 1,
#  'infinite': 2,
#  'memory': 1,
#  'approximate': 2,
#  'combination': 2,
#  'best': 3,
#  'citation': 1,
#  'needed': 3,
#  'therefore': 2,
#  'derive': 1,
#  'considering': 2,
#  'every': 5,
#  'hypothesis': 1,
#  'matching': 1,
#  'practice': 1,
#  'seldom': 1,
#  'combinatorial': 3,
#  'explosion': 3,
#  'grows': 1,
#  'exponentially': 3,
#  'Much': 2,
#  'involves': 2,
#  'figuring': 2,
#  'identify': 1,
#  'avoid': 3,
#  'broad': 1,
#  'range': 2,
#  'possibilities': 1,
#  'unlikely': 1,
#  'beneficial': 2,
#  'viewing': 1,
#  'map': 2,
#  'looking': 2,
#  'shortest': 1,
#  'driving': 3,
#  'route': 2,
#  'Denver': 1,
#  'New': 1,
#  'York': 1,
#  'East': 1,
#  'cases': 3,
#  'skip': 1,
#  'path': 1,
#  'San': 1,
#  'Francisco': 1,
#  'far': 5,
#  'West': 1,
#  'thus': 5,
#  'wielding': 1,
#  'pathfinding': 1,
#  'ensue': 1,
#  'ponderously': 1,
#  'earliest': 1,
#  'easiest': 1,
#  'understand': 3,
#  'approach': 11,
#  'symbolism': 1,
#  'healthy': 1,
#  'adult': 2,
#  'fever': 2,
#  'influenza': 3,
#  'general': 10,
#  'inference': 1,
#  'current': 8,
#  'patient': 3,
#  'adjust': 1,
#  'way': 5,
#  'third': 1,
#  'major': 3,
#  'extremely': 4,
#  'popular': 4,
#  'business': 1,
#  'applications': 8,
#  'analogizers': 1,
#  'SVM': 1,
#  'examining': 1,
#  'records': 1,
#  'patients': 2,
#  'temperature': 1,
#  'symptoms': 1,
#  'age': 1,
#  'mostly': 1,
#  'X': 2,
#  'turned': 1,
#  'fourth': 1,
#  'harder': 1,
#  'intuitively': 1,
#  'works': 4,
#  'comparing': 2,
#  'desired': 1,
#  'altering': 2,
#  'strengths': 1,
#  'connections': 2,
#  'internal': 1,
#  'reinforce': 1,
#  'seemed': 2,
#  'useful': 1,
#  'four': 1,
#  'main': 1,
#  'overlap': 1,
#  'nets': 1,
#  'make': 12,
#  'inferences': 5,
#  'generalize': 2,
#  'analogies': 1,
#  'multiple': 1,
#  'alongside': 1,
#  'different': 8,
#  'depending': 1,
#  'Learning': 1,
#  'basis': 2,
#  'likely': 3,
#  'continue': 3,
#  'working': 1,
#  'obvious': 1,
#  'sun': 1,
#  'rose': 1,
#  'morning': 2,
#  'last': 1,
#  'days': 1,
#  'probably': 1,
#  'tomorrow': 1,
#  'nuanced': 1,
#  'families': 1,
#  'geographically': 1,
#  'separate': 1,
#  'species': 1,
#  'color': 3,
#  'variants': 1,
#  'Y': 1,
#  'undiscovered': 2,
#  'black': 3,
#  'swans': 1,
#  'exist': 2,
#  'Learners': 1,
#  'Occam': 2,
#  'razor': 2,
#  'simplest': 1,
#  'explains': 1,
#  'likeliest': 1,
#  'Therefore': 1,
#  'according': 1,
#  'principle': 2,
#  'learner': 1,
#  'must': 4,
#  'designed': 2,
#  'prefers': 1,
#  'theories': 3,
#  'proven': 1,
#  'Settling': 1,
#  'bad': 2,
#  'overly': 1,
#  'gerrymandered': 1,
#  'fit': 1,
#  'overfitting': 3,
#  'attempt': 6,
#  'reduce': 2,
#  'accordance': 2,
#  'fits': 1,
#  'penalizing': 1,
#  'Besides': 2,
#  'classic': 1,
#  'disappoint': 1,
#  'wrong': 1,
#  'lesson': 1,
#  'toy': 3,
#  'classifier': 2,
#  'trained': 1,
#  'pictures': 1,
#  'brown': 2,
#  'horses': 2,
#  'cats': 1,
#  'might': 6,
#  'conclude': 1,
#  'patches': 2,
#  'real': 7,
#  'classifiers': 2,
#  'primarily': 1,
#  'judgments': 2,
#  'spatial': 1,
#  'relationship': 6,
#  'components': 1,
#  'picture': 1,
#  'relationships': 1,
#  'pixels': 2,
#  'oblivious': 1,
#  'correlate': 1,
#  'Modifying': 1,
#  'patterns': 2,
#  'legitimate': 1,
#  'result': 1,
#  'adversarial': 1,
#  'misclassifies': 1,
#  'Compared': 2,
#  'existing': 4,
#  'lacks': 1,
#  'features': 2,
#  'commonsense': 4,
#  'notably': 2,
#  'powerful': 4,
#  'mechanisms': 3,
#  'na': 2,
#  'physics': 1,
#  'space': 2,
#  'physical': 3,
#  'interactions': 1,
#  'enables': 1,
#  'even': 9,
#  'young': 2,
#  'children': 1,
#  'easily': 2,
#  'I': 6,
#  'roll': 1,
#  'pen': 1,
#  'table': 1,
#  'fall': 1,
#  'floor': 1,
#  'Humans': 3,
#  'mechanism': 1,
#  'folk': 1,
#  'helps': 1,
#  'sentences': 1,
#  'city': 1,
#  'councilmen': 2,
#  'refused': 1,
#  'demonstrators': 2,
#  'permit': 1,
#  'advocated': 2,
#  'violence': 2,
#  'generic': 1,
#  'discerning': 1,
#  'alleged': 1,
#  'advocating': 1,
#  'lack': 1,
#  'means': 2,
#  'makes': 4,
#  'mistakes': 1,
#  'ways': 2,
#  'seem': 1,
#  'incomprehensible': 1,
#  'self': 4,
#  'location': 2,
#  'intentions': 1,
#  'pedestrians': 2,
#  'exact': 1,
#  'modes': 1,
#  'accidents': 1,
#  'architectures': 4,
#  'limited': 2,
#  'simplified': 1,
#  'version': 1,
#  'really': 2,
#  'come': 4,
#  'beyond': 2,
#  'measure': 1,
#  'explanations': 1,
#  'occurrences': 1,
#  'life': 2,
#  'What': 1,
#  'straightforward': 4,
#  'equivalently': 1,
#  'computationally': 1,
#  'opposed': 2,
#  'gives': 1,
#  'classes': 2,
#  'models': 6,
#  'structuralist': 1,
#  'functionalist': 1,
#  'structural': 1,
#  ...}

# %% [markdown]
# ### Weighted Frequency Calculation

# %%
def weighted_freq(word_frequencies):
    maximum_frequncy = sum(word_frequencies.values())

    for word in word_frequencies.keys():
        word_frequencies[word] = (word_frequencies[word]/maximum_frequncy)
    
    return word_frequencies

# %%
weighted_freq(word_frequencies)
# Out:
# {'Artificial': 0.0011982197877440075,
#  'intelligence': 0.012495720643616079,
#  'AI': 0.024477918521056158,
#  'demonstrated': 0.0001711742553920011,
#  'machines': 0.003937007874016025,
#  'unlike': 0.0008558712769600055,
#  'natural': 0.001711742553920011,
#  'displayed': 0.0003423485107840022,
#  'humans': 0.004279356384800027,
#  'animals': 0.0003423485107840022,
#  'Leading': 0.0003423485107840022,
#  'textbooks': 0.0001711742553920011,
#  'define': 0.0001711742553920011,
#  'field': 0.0029099623416640186,
#  'study': 0.0010270455323520065,
#  'intelligent': 0.0029099623416640186,
#  'agents': 0.0013693940431360088,
#  'device': 0.0003423485107840022,
#  'perceives': 0.0003423485107840022,
#  'environment': 0.0010270455323520065,
#  'takes': 0.0005135227661760033,
#  'actions': 0.0015405682985280098,
#  'maximize': 0.0006846970215680044,
#  'chance': 0.0006846970215680044,
#  'successfully': 0.0010270455323520065,
#  'achieving': 0.0005135227661760033,
#  'goals': 0.002396439575488015,
#  'Colloquially': 0.0001711742553920011,
#  'term': 0.0011982197877440075,
#  'artificial': 0.008729887024992056,
#  'often': 0.002396439575488015,
#  'used': 0.0025676138308800165,
#  'describe': 0.0005135227661760033,
#  'computers': 0.001711742553920011,
#  'mimic': 0.0005135227661760033,
#  'cognitive': 0.0008558712769600055,
#  'functions': 0.0003423485107840022,
#  'associate': 0.0001711742553920011,
#  'human': 0.009756932557344063,
#  'mind': 0.0030811365970560196,
#  'learning': 0.00479287915097603,
#  'problem': 0.003423485107840022,
#  'solving': 0.0013693940431360088,
#  'As': 0.0003423485107840022,
#  'become': 0.0011982197877440075,
#  'increasingly': 0.0003423485107840022,
#  'capable': 0.0013693940431360088,
#  'tasks': 0.0008558712769600055,
#  'considered': 0.0015405682985280098,
#  'require': 0.0006846970215680044,
#  'removed': 0.0001711742553920011,
#  'definition': 0.0005135227661760033,
#  'phenomenon': 0.0005135227661760033,
#  'known': 0.0013693940431360088,
#  'effect': 0.0005135227661760033,
#  'A': 0.004964053406368032,
#  'quip': 0.0001711742553920011,
#  'Tesler': 0.0001711742553920011,
#  'Theorem': 0.0001711742553920011,
#  'says': 0.0001711742553920011,
#  'whatever': 0.0001711742553920011,
#  'done': 0.0001711742553920011,
#  'yet': 0.0001711742553920011,
#  'For': 0.001711742553920011,
#  'instance': 0.0003423485107840022,
#  'optical': 0.0001711742553920011,
#  'character': 0.0003423485107840022,
#  'recognition': 0.0010270455323520065,
#  'frequently': 0.0001711742553920011,
#  'excluded': 0.0001711742553920011,
#  'things': 0.0010270455323520065,
#  'routine': 0.0005135227661760033,
#  'technology': 0.0025676138308800165,
#  'Modern': 0.0005135227661760033,
#  'machine': 0.004108182129408026,
#  'capabilities': 0.0006846970215680044,
#  'generally': 0.0011982197877440075,
#  'classified': 0.0001711742553920011,
#  'include': 0.001711742553920011,
#  'understanding': 0.001882916809312012,
#  'speech': 0.0003423485107840022,
#  'competing': 0.0003423485107840022,
#  'highest': 0.0001711742553920011,
#  'level': 0.0015405682985280098,
#  'strategic': 0.0001711742553920011,
#  'game': 0.0008558712769600055,
#  'systems': 0.003594659363232023,
#  'chess': 0.0005135227661760033,
#  'Go': 0.001711742553920011,
#  'autonomously': 0.0001711742553920011,
#  'operating': 0.0003423485107840022,
#  'cars': 0.0006846970215680044,
#  'routing': 0.0001711742553920011,
#  'content': 0.0005135227661760033,
#  'delivery': 0.0001711742553920011,
#  'networks': 0.001711742553920011,
#  'military': 0.0001711742553920011,
#  'simulations': 0.0001711742553920011,
#  'founded': 0.0003423485107840022,
#  'academic': 0.0005135227661760033,
#  'discipline': 0.0003423485107840022,
#  'years': 0.0010270455323520065,
#  'since': 0.0011982197877440075,
#  'experienced': 0.0005135227661760033,
#  'several': 0.0005135227661760033,
#  'waves': 0.0003423485107840022,
#  'optimism': 0.0001711742553920011,
#  'followed': 0.0005135227661760033,
#  'disappointment': 0.0001711742553920011,
#  'loss': 0.0001711742553920011,
#  'funding': 0.0008558712769600055,
#  'winter': 0.0003423485107840022,
#  'new': 0.0013693940431360088,
#  'approaches': 0.002396439575488015,
#  'success': 0.0008558712769600055,
#  'renewed': 0.0001711742553920011,
#  'After': 0.0003423485107840022,
#  'AlphaGo': 0.0005135227661760033,
#  'defeated': 0.0003423485107840022,
#  'professional': 0.0003423485107840022,
#  'player': 0.0005135227661760033,
#  'attracted': 0.0001711742553920011,
#  'widespread': 0.0001711742553920011,
#  'global': 0.0001711742553920011,
#  'attention': 0.0003423485107840022,
#  'history': 0.0003423485107840022,
#  'research': 0.006333447449504041,
#  'divided': 0.0001711742553920011,
#  'sub': 0.0006846970215680044,
#  'fields': 0.0011982197877440075,
#  'fail': 0.0001711742553920011,
#  'communicate': 0.0001711742553920011,
#  'These': 0.0015405682985280098,
#  'based': 0.0015405682985280098,
#  'technical': 0.0001711742553920011,
#  'considerations': 0.0001711742553920011,
#  'particular': 0.0013693940431360088,
#  'e': 0.0006846970215680044,
#  'g': 0.0006846970215680044,
#  'robotics': 0.0011982197877440075,
#  'use': 0.003937007874016025,
#  'tools': 0.0008558712769600055,
#  'logic': 0.001882916809312012,
#  'neural': 0.001711742553920011,
#  'deep': 0.0005135227661760033,
#  'philosophical': 0.0010270455323520065,
#  'differences': 0.0001711742553920011,
#  'Sub': 0.0003423485107840022,
#  'also': 0.00479287915097603,
#  'social': 0.0015405682985280098,
#  'factors': 0.0003423485107840022,
#  'institutions': 0.0003423485107840022,
#  'work': 0.001882916809312012,
#  'researchers': 0.0027387880862720176,
#  'The': 0.00958575830195206,
#  'traditional': 0.0005135227661760033,
#  'problems': 0.003937007874016025,
#  'reasoning': 0.002225265320096014,
#  'knowledge': 0.005135227661760033,
#  'representation': 0.0010270455323520065,
#  'planning': 0.0008558712769600055,
#  'language': 0.002054091064704013,
#  'processing': 0.001711742553920011,
#  'perception': 0.0010270455323520065,
#  'ability': 0.0015405682985280098,
#  'move': 0.0005135227661760033,
#  'manipulate': 0.0001711742553920011,
#  'objects': 0.0008558712769600055,
#  'General': 0.0001711742553920011,
#  'among': 0.0005135227661760033,
#  'long': 0.0010270455323520065,
#  'Approaches': 0.0003423485107840022,
#  'statistical': 0.0011982197877440075,
#  'methods': 0.0011982197877440075,
#  'computational': 0.0010270455323520065,
#  'symbolic': 0.002054091064704013,
#  'Many': 0.0015405682985280098,
#  'including': 0.0015405682985280098,
#  'versions': 0.0001711742553920011,
#  'search': 0.0008558712769600055,
#  'mathematical': 0.0013693940431360088,
#  'optimization': 0.0005135227661760033,
#  'statistics': 0.0003423485107840022,
#  'probability': 0.0005135227661760033,
#  'economics': 0.0006846970215680044,
#  'draws': 0.0001711742553920011,
#  'upon': 0.0005135227661760033,
#  'computer': 0.0030811365970560196,
#  'science': 0.0015405682985280098,
#  'information': 0.0013693940431360088,
#  'engineering': 0.0008558712769600055,
#  'mathematics': 0.0005135227661760033,
#  'psychology': 0.0005135227661760033,
#  'linguistics': 0.0001711742553920011,
#  'philosophy': 0.0005135227661760033,
#  'many': 0.003594659363232023,
#  'assumption': 0.0001711742553920011,
#  'precisely': 0.0001711742553920011,
#  'described': 0.001711742553920011,
#  'made': 0.0001711742553920011,
#  'simulate': 0.0011982197877440075,
#  'This': 0.0032523108524480206,
#  'raises': 0.0001711742553920011,
#  'arguments': 0.0001711742553920011,
#  'ethics': 0.002225265320096014,
#  'creating': 0.0008558712769600055,
#  'beings': 0.0013693940431360088,
#  'endowed': 0.0001711742553920011,
#  'like': 0.002396439575488015,
#  'issues': 0.0008558712769600055,
#  'explored': 0.0005135227661760033,
#  'myth': 0.0001711742553920011,
#  'fiction': 0.0010270455323520065,
#  'antiquity': 0.0006846970215680044,
#  'Some': 0.002054091064704013,
#  'people': 0.002225265320096014,
#  'consider': 0.0008558712769600055,
#  'danger': 0.0003423485107840022,
#  'humanity': 0.0010270455323520065,
#  'progresses': 0.0001711742553920011,
#  'unabated': 0.0001711742553920011,
#  'Others': 0.0001711742553920011,
#  'believe': 0.0013693940431360088,
#  'previous': 0.0003423485107840022,
#  'technological': 0.0003423485107840022,
#  'revolutions': 0.0001711742553920011,
#  'create': 0.0005135227661760033,
#  'risk': 0.001711742553920011,
#  'mass': 0.0001711742553920011,
#  'unemployment': 0.0003423485107840022,
#  'In': 0.003765833618624024,
#  'twenty': 0.0003423485107840022,
#  'first': 0.001882916809312012,
#  'century': 0.0003423485107840022,
#  'techniques': 0.0010270455323520065,
#  'resurgence': 0.0001711742553920011,
#  'following': 0.0003423485107840022,
#  'concurrent': 0.0003423485107840022,
#  'advances': 0.0006846970215680044,
#  'power': 0.0008558712769600055,
#  'large': 0.001711742553920011,
#  'amounts': 0.0005135227661760033,
#  'data': 0.003765833618624024,
#  'theoretical': 0.0001711742553920011,
#  'essential': 0.0001711742553920011,
#  'part': 0.0005135227661760033,
#  'industry': 0.0003423485107840022,
#  'helping': 0.0001711742553920011,
#  'solve': 0.0013693940431360088,
#  'challenging': 0.0003423485107840022,
#  'software': 0.0015405682985280098,
#  'operations': 0.0006846970215680044,
#  'Thought': 0.0003423485107840022,
#  'appeared': 0.0003423485107840022,
#  'storytelling': 0.0003423485107840022,
#  'devices': 0.0003423485107840022,
#  'common': 0.0005135227661760033,
#  'Mary': 0.0003423485107840022,
#  'Shelley': 0.0003423485107840022,
#  'Frankenstein': 0.0003423485107840022,
#  'Karel': 0.0003423485107840022,
#  'apek': 0.0003423485107840022,
#  'R': 0.0006846970215680044,
#  'U': 0.0013693940431360088,
#  'characters': 0.0001711742553920011,
#  'fates': 0.0001711742553920011,
#  'raised': 0.0001711742553920011,
#  'discussed': 0.0005135227661760033,
#  'mechanical': 0.0003423485107840022,
#  'formal': 0.0010270455323520065,
#  'began': 0.0011982197877440075,
#  'philosophers': 0.0005135227661760033,
#  'mathematicians': 0.0001711742553920011,
#  'led': 0.0010270455323520065,
#  'directly': 0.0003423485107840022,
#  'Alan': 0.0001711742553920011,
#  'Turing': 0.0006846970215680044,
#  'theory': 0.0027387880862720176,
#  'computation': 0.0005135227661760033,
#  'suggested': 0.0001711742553920011,
#  'shuffling': 0.0001711742553920011,
#  'symbols': 0.0001711742553920011,
#  'simple': 0.0010270455323520065,
#  'could': 0.004108182129408026,
#  'conceivable': 0.0001711742553920011,
#  'act': 0.0001711742553920011,
#  'deduction': 0.0003423485107840022,
#  'insight': 0.0001711742553920011,
#  'digital': 0.0006846970215680044,
#  'process': 0.0006846970215680044,
#  'Church': 0.0001711742553920011,
#  'thesis': 0.0003423485107840022,
#  'Along': 0.0001711742553920011,
#  'discoveries': 0.0001711742553920011,
#  'neurobiology': 0.0005135227661760033,
#  'cybernetics': 0.0008558712769600055,
#  'possibility': 0.0008558712769600055,
#  'building': 0.0005135227661760033,
#  'electronic': 0.0003423485107840022,
#  'brain': 0.0013693940431360088,
#  'proposed': 0.0006846970215680044,
#  'changing': 0.0003423485107840022,
#  'question': 0.0011982197877440075,
#  'whether': 0.0011982197877440075,
#  'possible': 0.001711742553920011,
#  'machinery': 0.0005135227661760033,
#  'show': 0.0003423485107840022,
#  'behaviour': 0.0001711742553920011,
#  'recognized': 0.0001711742553920011,
#  'McCullouch': 0.0001711742553920011,
#  'Pitts': 0.0001711742553920011,
#  'design': 0.0001711742553920011,
#  'complete': 0.0005135227661760033,
#  'neurons': 0.0005135227661760033,
#  'born': 0.0003423485107840022,
#  'workshop': 0.0001711742553920011,
#  'Dartmouth': 0.0001711742553920011,
#  'College': 0.0001711742553920011,
#  'Intelligence': 0.0006846970215680044,
#  'coined': 0.0001711742553920011,
#  'John': 0.0008558712769600055,
#  'McCarthy': 0.0005135227661760033,
#  'distinguish': 0.0001711742553920011,
#  'escape': 0.0003423485107840022,
#  'influence': 0.0001711742553920011,
#  'cyberneticist': 0.0003423485107840022,
#  'Norbert': 0.0001711742553920011,
#  'Wiener': 0.0001711742553920011,
#  'Attendees': 0.0001711742553920011,
#  'Allen': 0.0003423485107840022,
#  'Newell': 0.0005135227661760033,
#  'CMU': 0.0005135227661760033,
#  'Herbert': 0.0005135227661760033,
#  'Simon': 0.0006846970215680044,
#  'MIT': 0.0006846970215680044,
#  'Marvin': 0.0005135227661760033,
#  'Minsky': 0.0005135227661760033,
#  'Arthur': 0.0003423485107840022,
#  'Samuel': 0.0003423485107840022,
#  'IBM': 0.0003423485107840022,
#  'became': 0.0008558712769600055,
#  'founders': 0.0003423485107840022,
#  'leaders': 0.0003423485107840022,
#  'They': 0.0008558712769600055,
#  'students': 0.0001711742553920011,
#  'produced': 0.0003423485107840022,
#  'programs': 0.0006846970215680044,
#  'press': 0.0001711742553920011,
#  'astonishing': 0.0001711742553920011,
#  'checkers': 0.0005135227661760033,
#  'strategies': 0.0010270455323520065,
#  'c': 0.0005135227661760033,
#  'reportedly': 0.0001711742553920011,
#  'playing': 0.0008558712769600055,
#  'better': 0.0011982197877440075,
#  'average': 0.0008558712769600055,
#  'word': 0.0006846970215680044,
#  'algebra': 0.0001711742553920011,
#  'proving': 0.0003423485107840022,
#  'logical': 0.0006846970215680044,
#  'theorems': 0.0003423485107840022,
#  'Logic': 0.0005135227661760033,
#  'Theorist': 0.0001711742553920011,
#  'run': 0.0003423485107840022,
#  'speaking': 0.0001711742553920011,
#  'English': 0.0001711742553920011,
#  'By': 0.0010270455323520065,
#  'middle': 0.0006846970215680044,
#  'S': 0.0010270455323520065,
#  'heavily': 0.0003423485107840022,
#  'funded': 0.0001711742553920011,
#  'Department': 0.0001711742553920011,
#  'Defense': 0.0001711742553920011,
#  'laboratories': 0.0001711742553920011,
#  'established': 0.0005135227661760033,
#  'around': 0.0010270455323520065,
#  'world': 0.002054091064704013,
#  'optimistic': 0.0001711742553920011,
#  'future': 0.0008558712769600055,
#  'predicted': 0.0003423485107840022,
#  'within': 0.0006846970215680044,
#  'man': 0.0001711742553920011,
#  'agreed': 0.0001711742553920011,
#  'writing': 0.0001711742553920011,
#  'generation': 0.0003423485107840022,
#  'substantially': 0.0003423485107840022,
#  'solved': 0.0005135227661760033,
#  'failed': 0.0005135227661760033,
#  'recognize': 0.0003423485107840022,
#  'difficulty': 0.0008558712769600055,
#  'remaining': 0.0001711742553920011,
#  'Progress': 0.0001711742553920011,
#  'slowed': 0.0001711742553920011,
#  'response': 0.0001711742553920011,
#  'criticism': 0.0001711742553920011,
#  'Sir': 0.0001711742553920011,
#  'James': 0.0001711742553920011,
#  'Lighthill': 0.0001711742553920011,
#  'ongoing': 0.0001711742553920011,
#  'pressure': 0.0001711742553920011,
#  'US': 0.0001711742553920011,
#  'Congress': 0.0001711742553920011,
#  'fund': 0.0003423485107840022,
#  'productive': 0.0001711742553920011,
#  'projects': 0.0011982197877440075,
#  'British': 0.0003423485107840022,
#  'governments': 0.0003423485107840022,
#  'cut': 0.0001711742553920011,
#  'exploratory': 0.0001711742553920011,
#  'next': 0.0006846970215680044,
#  'would': 0.00479287915097603,
#  'later': 0.0005135227661760033,
#  'called': 0.0005135227661760033,
#  'period': 0.0001711742553920011,
#  'obtaining': 0.0001711742553920011,
#  'difficult': 0.001711742553920011,
#  'early': 0.0008558712769600055,
#  'revived': 0.0006846970215680044,
#  'commercial': 0.0003423485107840022,
#  'expert': 0.0006846970215680044,
#  'form': 0.0015405682985280098,
#  'program': 0.0008558712769600055,
#  'simulated': 0.0005135227661760033,
#  'analytical': 0.0001711742553920011,
#  'skills': 0.0011982197877440075,
#  'experts': 0.0006846970215680044,
#  'market': 0.0003423485107840022,
#  'reached': 0.0001711742553920011,
#  'billion': 0.0003423485107840022,
#  'dollars': 0.0001711742553920011,
#  'At': 0.0001711742553920011,
#  'time': 0.0013693940431360088,
#  'Japan': 0.0003423485107840022,
#  'fifth': 0.0001711742553920011,
#  'project': 0.0001711742553920011,
#  'inspired': 0.0005135227661760033,
#  'restore': 0.0001711742553920011,
#  'However': 0.0006846970215680044,
#  'beginning': 0.0001711742553920011,
#  'collapse': 0.0001711742553920011,
#  'Lisp': 0.0001711742553920011,
#  'Machine': 0.0011982197877440075,
#  'fell': 0.0001711742553920011,
#  'disrepute': 0.0001711742553920011,
#  'second': 0.0003423485107840022,
#  'longer': 0.0003423485107840022,
#  'lasting': 0.0001711742553920011,
#  'hiatus': 0.0001711742553920011,
#  'development': 0.002396439575488015,
#  'metal': 0.0001711742553920011,
#  'oxide': 0.0001711742553920011,
#  'semiconductor': 0.0001711742553920011,
#  'MOS': 0.0003423485107840022,
#  'scale': 0.0001711742553920011,
#  'integration': 0.0001711742553920011,
#  'VLSI': 0.0003423485107840022,
#  'complementary': 0.0001711742553920011,
#  'CMOS': 0.0001711742553920011,
#  'transistor': 0.0003423485107840022,
#  'enabled': 0.0003423485107840022,
#  'practical': 0.0003423485107840022,
#  'network': 0.0003423485107840022,
#  'ANN': 0.0001711742553920011,
#  'landmark': 0.0003423485107840022,
#  'publication': 0.0001711742553920011,
#  'book': 0.0010270455323520065,
#  'Analog': 0.0001711742553920011,
#  'Implementation': 0.0001711742553920011,
#  'Neural': 0.0001711742553920011,
#  'Systems': 0.0003423485107840022,
#  'Carver': 0.0001711742553920011,
#  'Mead': 0.0001711742553920011,
#  'Mohammed': 0.0001711742553920011,
#  'Ismail': 0.0001711742553920011,
#  'late': 0.0003423485107840022,
#  'st': 0.0001711742553920011,
#  'logistics': 0.0001711742553920011,
#  'mining': 0.0006846970215680044,
#  'medical': 0.0005135227661760033,
#  'diagnosis': 0.0006846970215680044,
#  'areas': 0.0006846970215680044,
#  'due': 0.0003423485107840022,
#  'increasing': 0.0011982197877440075,
#  'see': 0.0006846970215680044,
#  'Moore': 0.0003423485107840022,
#  'law': 0.0003423485107840022,
#  'count': 0.0001711742553920011,
#  'greater': 0.0003423485107840022,
#  'emphasis': 0.0003423485107840022,
#  'specific': 0.0010270455323520065,
#  'ties': 0.0001711742553920011,
#  'commitment': 0.0001711742553920011,
#  'scientific': 0.0003423485107840022,
#  'standards': 0.0001711742553920011,
#  'Deep': 0.0001711742553920011,
#  'Blue': 0.0001711742553920011,
#  'system': 0.003423485107840022,
#  'beat': 0.0003423485107840022,
#  'reigning': 0.0001711742553920011,
#  'champion': 0.0003423485107840022,
#  'Garry': 0.0001711742553920011,
#  'Kasparov': 0.0001711742553920011,
#  'May': 0.0001711742553920011,
#  'Jeopardy': 0.0003423485107840022,
#  'quiz': 0.0001711742553920011,
#  'exhibition': 0.0001711742553920011,
#  'match': 0.0008558712769600055,
#  'answering': 0.0003423485107840022,
#  'Watson': 0.0001711742553920011,
#  'two': 0.0010270455323520065,
#  'greatest': 0.0001711742553920011,
#  'champions': 0.0001711742553920011,
#  'Brad': 0.0001711742553920011,
#  'Rutter': 0.0001711742553920011,
#  'Ken': 0.0001711742553920011,
#  'Jennings': 0.0001711742553920011,
#  'significant': 0.0003423485107840022,
#  'margin': 0.0001711742553920011,
#  'Faster': 0.0001711742553920011,
#  'algorithmic': 0.0003423485107840022,
#  'improvements': 0.0003423485107840022,
#  'access': 0.0003423485107840022,
#  'hungry': 0.0001711742553920011,
#  'started': 0.0001711742553920011,
#  'dominate': 0.0001711742553920011,
#  'accuracy': 0.0005135227661760033,
#  'benchmarks': 0.0001711742553920011,
#  'Kinect': 0.0001711742553920011,
#  'provides': 0.0003423485107840022,
#  'D': 0.0001711742553920011,
#  'body': 0.0008558712769600055,
#  'motion': 0.0003423485107840022,
#  'interface': 0.0001711742553920011,
#  'Xbox': 0.0003423485107840022,
#  'One': 0.0006846970215680044,
#  'uses': 0.0008558712769600055,
#  'algorithms': 0.002396439575488015,
#  'emerged': 0.0001711742553920011,
#  'lengthy': 0.0001711742553920011,
#  'personal': 0.0003423485107840022,
#  'assistants': 0.0005135227661760033,
#  'smartphones': 0.0001711742553920011,
#  'March': 0.0001711742553920011,
#  'games': 0.0005135227661760033,
#  'Lee': 0.0001711742553920011,
#  'Sedol': 0.0001711742553920011,
#  'becoming': 0.0006846970215680044,
#  'without': 0.0010270455323520065,
#  'handicaps': 0.0001711742553920011,
#  'Future': 0.0006846970215680044,
#  'Summit': 0.0001711742553920011,
#  'three': 0.0006846970215680044,
#  'Ke': 0.0001711742553920011,
#  'Jie': 0.0001711742553920011,
#  'continuously': 0.0001711742553920011,
#  'held': 0.0001711742553920011,
#  'No': 0.0003423485107840022,
#  'ranking': 0.0001711742553920011,
#  'marked': 0.0001711742553920011,
#  'completion': 0.0001711742553920011,
#  'milestone': 0.0001711742553920011,
#  'relatively': 0.0001711742553920011,
#  'complex': 0.0011982197877440075,
#  'Chess': 0.0003423485107840022,
#  'According': 0.0001711742553920011,
#  'Bloomberg': 0.0001711742553920011,
#  'Jack': 0.0001711742553920011,
#  'Clark': 0.0003423485107840022,
#  'year': 0.0006846970215680044,
#  'number': 0.0008558712769600055,
#  'Google': 0.0003423485107840022,
#  'increased': 0.0003423485107840022,
#  'sporadic': 0.0001711742553920011,
#  'usage': 0.0001711742553920011,
#  'presents': 0.0003423485107840022,
#  'factual': 0.0001711742553920011,
#  'indicating': 0.0001711742553920011,
#  'supported': 0.0001711742553920011,
#  'lower': 0.0001711742553920011,
#  'error': 0.0003423485107840022,
#  'rates': 0.0001711742553920011,
#  'image': 0.0008558712769600055,
#  'He': 0.0006846970215680044,
#  'attributes': 0.0001711742553920011,
#  'increase': 0.0010270455323520065,
#  'affordable': 0.0001711742553920011,
#  'rise': 0.0005135227661760033,
#  'cloud': 0.0001711742553920011,
#  'computing': 0.0011982197877440075,
#  'infrastructure': 0.0001711742553920011,
#  'datasets': 0.0003423485107840022,
#  'Other': 0.0006846970215680044,
#  'cited': 0.0001711742553920011,
#  'examples': 0.0005135227661760033,
#  'Microsoft': 0.0003423485107840022,
#  'Skype': 0.0001711742553920011,
#  'automatically': 0.0003423485107840022,
#  'translate': 0.0001711742553920011,
#  'one': 0.0015405682985280098,
#  'another': 0.0001711742553920011,
#  'Facebook': 0.0003423485107840022,
#  'images': 0.0005135227661760033,
#  'blind': 0.0003423485107840022,
#  'survey': 0.0003423485107840022,
#  'five': 0.0001711742553920011,
#  'companies': 0.0003423485107840022,
#  'reported': 0.0001711742553920011,
#  'incorporated': 0.0003423485107840022,
#  'offerings': 0.0001711742553920011,
#  'processes': 0.0006846970215680044,
#  'Around': 0.0001711742553920011,
#  'China': 0.0005135227661760033,
#  'greatly': 0.0003423485107840022,
#  'accelerated': 0.0001711742553920011,
#  'government': 0.0001711742553920011,
#  'given': 0.0008558712769600055,
#  'supply': 0.0001711742553920011,
#  'rapidly': 0.0001711742553920011,
#  'output': 0.0003423485107840022,
#  'observers': 0.0001711742553920011,
#  'may': 0.0030811365970560196,
#  'track': 0.0001711742553920011,
#  'superpower': 0.0001711742553920011,
#  'acknowledged': 0.0001711742553920011,
#  'reports': 0.0003423485107840022,
#  'regarding': 0.0001711742553920011,
#  'tended': 0.0003423485107840022,
#  'exaggerated': 0.0001711742553920011,
#  'Computer': 0.0006846970215680044,
#  'defines': 0.0001711742553920011,
#  'elaborate': 0.0001711742553920011,
#  'characterizes': 0.0001711742553920011,
#  'correctly': 0.0001711742553920011,
#  'interpret': 0.0006846970215680044,
#  'external': 0.0001711742553920011,
#  'learn': 0.0013693940431360088,
#  'learnings': 0.0001711742553920011,
#  'achieve': 0.0010270455323520065,
#  'flexible': 0.0001711742553920011,
#  'adaptation': 0.0003423485107840022,
#  'typical': 0.0001711742553920011,
#  'analyzes': 0.0001711742553920011,
#  'An': 0.0005135227661760033,
#  'intended': 0.0001711742553920011,
#  'utility': 0.0003423485107840022,
#  'function': 0.001711742553920011,
#  'goal': 0.002054091064704013,
#  'wins': 0.0001711742553920011,
#  'otherwise': 0.0008558712769600055,
#  'Perform': 0.0001711742553920011,
#  'mathematically': 0.0003423485107840022,
#  'similar': 0.0005135227661760033,
#  'ones': 0.0006846970215680044,
#  'succeeded': 0.0001711742553920011,
#  'past': 0.0010270455323520065,
#  'Goals': 0.0001711742553920011,
#  'explicitly': 0.0003423485107840022,
#  'defined': 0.0001711742553920011,
#  'induced': 0.0003423485107840022,
#  'If': 0.001882916809312012,
#  'programmed': 0.0005135227661760033,
#  'reinforcement': 0.0005135227661760033,
#  'implicitly': 0.0003423485107840022,
#  'rewarding': 0.0003423485107840022,
#  'types': 0.0003423485107840022,
#  'behavior': 0.001711742553920011,
#  'punishing': 0.0001711742553920011,
#  'others': 0.0010270455323520065,
#  'Alternatively': 0.0001711742553920011,
#  'evolutionary': 0.0006846970215680044,
#  'induce': 0.0001711742553920011,
#  'using': 0.0013693940431360088,
#  'fitness': 0.0001711742553920011,
#  'mutate': 0.0001711742553920011,
#  'preferentially': 0.0001711742553920011,
#  'replicate': 0.0001711742553920011,
#  'high': 0.0011982197877440075,
#  'scoring': 0.0001711742553920011,
#  'evolved': 0.0003423485107840022,
#  'innately': 0.0001711742553920011,
#  'desire': 0.0001711742553920011,
#  'certain': 0.0005135227661760033,
#  'finding': 0.0001711742553920011,
#  'food': 0.0003423485107840022,
#  'nearest': 0.0005135227661760033,
#  'neighbor': 0.0005135227661760033,
#  'instead': 0.0006846970215680044,
#  'reason': 0.0010270455323520065,
#  'analogy': 0.0001711742553920011,
#  'except': 0.0003423485107840022,
#  'degree': 0.0003423485107840022,
#  'implicit': 0.0003423485107840022,
#  'training': 0.0003423485107840022,
#  'Such': 0.0006846970215680044,
#  'still': 0.0005135227661760033,
#  'benchmarked': 0.0001711742553920011,
#  'non': 0.0008558712769600055,
#  'framed': 0.0001711742553920011,
#  'whose': 0.0003423485107840022,
#  'accomplish': 0.0001711742553920011,
#  'narrow': 0.0008558712769600055,
#  'classification': 0.0003423485107840022,
#  'task': 0.0005135227661760033,
#  'revolves': 0.0001711742553920011,
#  'algorithm': 0.0006846970215680044,
#  'set': 0.0005135227661760033,
#  'unambiguous': 0.0001711742553920011,
#  'instructions': 0.0001711742553920011,
#  'execute': 0.0001711742553920011,
#  'b': 0.0001711742553920011,
#  'built': 0.0005135227661760033,
#  'top': 0.0001711742553920011,
#  'simpler': 0.0003423485107840022,
#  'example': 0.0032523108524480206,
#  'optimal': 0.0001711742553920011,
#  'recipe': 0.0001711742553920011,
#  'play': 0.0001711742553920011,
#  'tic': 0.0001711742553920011,
#  'tac': 0.0001711742553920011,
#  'toe': 0.0001711742553920011,
#  'enhance': 0.0001711742553920011,
#  'heuristics': 0.0001711742553920011,
#  'rules': 0.0003423485107840022,
#  'thumb': 0.0001711742553920011,
#  'worked': 0.0005135227661760033,
#  'well': 0.002225265320096014,
#  'write': 0.0003423485107840022,
#  'learners': 0.0008558712769600055,
#  'Bayesian': 0.0005135227661760033,
#  'decision': 0.0010270455323520065,
#  'trees': 0.0001711742553920011,
#  'theoretically': 0.0001711742553920011,
#  'infinite': 0.0003423485107840022,
#  'memory': 0.0001711742553920011,
#  'approximate': 0.0003423485107840022,
#  'combination': 0.0003423485107840022,
#  'best': 0.0005135227661760033,
#  'citation': 0.0001711742553920011,
#  'needed': 0.0005135227661760033,
#  'therefore': 0.0003423485107840022,
#  'derive': 0.0001711742553920011,
#  'considering': 0.0003423485107840022,
#  'every': 0.0008558712769600055,
#  'hypothesis': 0.0001711742553920011,
#  'matching': 0.0001711742553920011,
#  'practice': 0.0001711742553920011,
#  'seldom': 0.0001711742553920011,
#  'combinatorial': 0.0005135227661760033,
#  'explosion': 0.0005135227661760033,
#  'grows': 0.0001711742553920011,
#  'exponentially': 0.0005135227661760033,
#  'Much': 0.0003423485107840022,
#  'involves': 0.0003423485107840022,
#  'figuring': 0.0003423485107840022,
#  'identify': 0.0001711742553920011,
#  'avoid': 0.0005135227661760033,
#  'broad': 0.0001711742553920011,
#  'range': 0.0003423485107840022,
#  'possibilities': 0.0001711742553920011,
#  'unlikely': 0.0001711742553920011,
#  'beneficial': 0.0003423485107840022,
#  'viewing': 0.0001711742553920011,
#  'map': 0.0003423485107840022,
#  'looking': 0.0003423485107840022,
#  'shortest': 0.0001711742553920011,
#  'driving': 0.0005135227661760033,
#  'route': 0.0003423485107840022,
#  'Denver': 0.0001711742553920011,
#  'New': 0.0001711742553920011,
#  'York': 0.0001711742553920011,
#  'East': 0.0001711742553920011,
#  'cases': 0.0005135227661760033,
#  'skip': 0.0001711742553920011,
#  'path': 0.0001711742553920011,
#  'San': 0.0001711742553920011,
#  'Francisco': 0.0001711742553920011,
#  'far': 0.0008558712769600055,
#  'West': 0.0001711742553920011,
#  'thus': 0.0008558712769600055,
#  'wielding': 0.0001711742553920011,
#  'pathfinding': 0.0001711742553920011,
#  'ensue': 0.0001711742553920011,
#  'ponderously': 0.0001711742553920011,
#  'earliest': 0.0001711742553920011,
#  'easiest': 0.0001711742553920011,
#  'understand': 0.0005135227661760033,
#  'approach': 0.001882916809312012,
#  'symbolism': 0.0001711742553920011,
#  'healthy': 0.0001711742553920011,
#  'adult': 0.0003423485107840022,
#  'fever': 0.0003423485107840022,
#  'influenza': 0.0005135227661760033,
#  'general': 0.001711742553920011,
#  'inference': 0.0001711742553920011,
#  'current': 0.0013693940431360088,
#  'patient': 0.0005135227661760033,
#  'adjust': 0.0001711742553920011,
#  'way': 0.0008558712769600055,
#  'third': 0.0001711742553920011,
#  'major': 0.0005135227661760033,
#  'extremely': 0.0006846970215680044,
#  'popular': 0.0006846970215680044,
#  'business': 0.0001711742553920011,
#  'applications': 0.0013693940431360088,
#  'analogizers': 0.0001711742553920011,
#  'SVM': 0.0001711742553920011,
#  'examining': 0.0001711742553920011,
#  'records': 0.0001711742553920011,
#  'patients': 0.0003423485107840022,
#  'temperature': 0.0001711742553920011,
#  'symptoms': 0.0001711742553920011,
#  'age': 0.0001711742553920011,
#  'mostly': 0.0001711742553920011,
#  'X': 0.0003423485107840022,
#  'turned': 0.0001711742553920011,
#  'fourth': 0.0001711742553920011,
#  'harder': 0.0001711742553920011,
#  'intuitively': 0.0001711742553920011,
#  'works': 0.0006846970215680044,
#  'comparing': 0.0003423485107840022,
#  'desired': 0.0001711742553920011,
#  'altering': 0.0003423485107840022,
#  'strengths': 0.0001711742553920011,
#  'connections': 0.0003423485107840022,
#  'internal': 0.0001711742553920011,
#  'reinforce': 0.0001711742553920011,
#  'seemed': 0.0003423485107840022,
#  'useful': 0.0001711742553920011,
#  'four': 0.0001711742553920011,
#  'main': 0.0001711742553920011,
#  'overlap': 0.0001711742553920011,
#  'nets': 0.0001711742553920011,
#  'make': 0.002054091064704013,
#  'inferences': 0.0008558712769600055,
#  'generalize': 0.0003423485107840022,
#  'analogies': 0.0001711742553920011,
#  'multiple': 0.0001711742553920011,
#  'alongside': 0.0001711742553920011,
#  'different': 0.0013693940431360088,
#  'depending': 0.0001711742553920011,
#  'Learning': 0.0001711742553920011,
#  'basis': 0.0003423485107840022,
#  'likely': 0.0005135227661760033,
#  'continue': 0.0005135227661760033,
#  'working': 0.0001711742553920011,
#  'obvious': 0.0001711742553920011,
#  'sun': 0.0001711742553920011,
#  'rose': 0.0001711742553920011,
#  'morning': 0.0003423485107840022,
#  'last': 0.0001711742553920011,
#  'days': 0.0001711742553920011,
#  'probably': 0.0001711742553920011,
#  'tomorrow': 0.0001711742553920011,
#  'nuanced': 0.0001711742553920011,
#  'families': 0.0001711742553920011,
#  'geographically': 0.0001711742553920011,
#  'separate': 0.0001711742553920011,
#  'species': 0.0001711742553920011,
#  'color': 0.0005135227661760033,
#  'variants': 0.0001711742553920011,
#  'Y': 0.0001711742553920011,
#  'undiscovered': 0.0003423485107840022,
#  'black': 0.0005135227661760033,
#  'swans': 0.0001711742553920011,
#  'exist': 0.0003423485107840022,
#  'Learners': 0.0001711742553920011,
#  'Occam': 0.0003423485107840022,
#  'razor': 0.0003423485107840022,
#  'simplest': 0.0001711742553920011,
#  'explains': 0.0001711742553920011,
#  'likeliest': 0.0001711742553920011,
#  'Therefore': 0.0001711742553920011,
#  'according': 0.0001711742553920011,
#  'principle': 0.0003423485107840022,
#  'learner': 0.0001711742553920011,
#  'must': 0.0006846970215680044,
#  'designed': 0.0003423485107840022,
#  'prefers': 0.0001711742553920011,
#  'theories': 0.0005135227661760033,
#  'proven': 0.0001711742553920011,
#  'Settling': 0.0001711742553920011,
#  'bad': 0.0003423485107840022,
#  'overly': 0.0001711742553920011,
#  'gerrymandered': 0.0001711742553920011,
#  'fit': 0.0001711742553920011,
#  'overfitting': 0.0005135227661760033,
#  'attempt': 0.0010270455323520065,
#  'reduce': 0.0003423485107840022,
#  'accordance': 0.0003423485107840022,
#  'fits': 0.0001711742553920011,
#  'penalizing': 0.0001711742553920011,
#  'Besides': 0.0003423485107840022,
#  'classic': 0.0001711742553920011,
#  'disappoint': 0.0001711742553920011,
#  'wrong': 0.0001711742553920011,
#  'lesson': 0.0001711742553920011,
#  'toy': 0.0005135227661760033,
#  'classifier': 0.0003423485107840022,
#  'trained': 0.0001711742553920011,
#  'pictures': 0.0001711742553920011,
#  'brown': 0.0003423485107840022,
#  'horses': 0.0003423485107840022,
#  'cats': 0.0001711742553920011,
#  'might': 0.0010270455323520065,
#  'conclude': 0.0001711742553920011,
#  'patches': 0.0003423485107840022,
#  'real': 0.0011982197877440075,
#  'classifiers': 0.0003423485107840022,
#  'primarily': 0.0001711742553920011,
#  'judgments': 0.0003423485107840022,
#  'spatial': 0.0001711742553920011,
#  'relationship': 0.0010270455323520065,
#  'components': 0.0001711742553920011,
#  'picture': 0.0001711742553920011,
#  'relationships': 0.0001711742553920011,
#  'pixels': 0.0003423485107840022,
#  'oblivious': 0.0001711742553920011,
#  'correlate': 0.0001711742553920011,
#  'Modifying': 0.0001711742553920011,
#  'patterns': 0.0003423485107840022,
#  'legitimate': 0.0001711742553920011,
#  'result': 0.0001711742553920011,
#  'adversarial': 0.0001711742553920011,
#  'misclassifies': 0.0001711742553920011,
#  'Compared': 0.0003423485107840022,
#  'existing': 0.0006846970215680044,
#  'lacks': 0.0001711742553920011,
#  'features': 0.0003423485107840022,
#  'commonsense': 0.0006846970215680044,
#  'notably': 0.0003423485107840022,
#  'powerful': 0.0006846970215680044,
#  'mechanisms': 0.0005135227661760033,
#  'na': 0.0003423485107840022,
#  'physics': 0.0001711742553920011,
#  'space': 0.0003423485107840022,
#  'physical': 0.0005135227661760033,
#  'interactions': 0.0001711742553920011,
#  'enables': 0.0001711742553920011,
#  'even': 0.0015405682985280098,
#  'young': 0.0003423485107840022,
#  'children': 0.0001711742553920011,
#  'easily': 0.0003423485107840022,
#  'I': 0.0010270455323520065,
#  'roll': 0.0001711742553920011,
#  'pen': 0.0001711742553920011,
#  'table': 0.0001711742553920011,
#  'fall': 0.0001711742553920011,
#  'floor': 0.0001711742553920011,
#  'Humans': 0.0005135227661760033,
#  'mechanism': 0.0001711742553920011,
#  'folk': 0.0001711742553920011,
#  'helps': 0.0001711742553920011,
#  'sentences': 0.0001711742553920011,
#  'city': 0.0001711742553920011,
#  'councilmen': 0.0003423485107840022,
#  'refused': 0.0001711742553920011,
#  'demonstrators': 0.0003423485107840022,
#  'permit': 0.0001711742553920011,
#  'advocated': 0.0003423485107840022,
#  'violence': 0.0003423485107840022,
#  'generic': 0.0001711742553920011,
#  'discerning': 0.0001711742553920011,
#  'alleged': 0.0001711742553920011,
#  'advocating': 0.0001711742553920011,
#  'lack': 0.0001711742553920011,
#  'means': 0.0003423485107840022,
#  'makes': 0.0006846970215680044,
#  'mistakes': 0.0001711742553920011,
#  'ways': 0.0003423485107840022,
#  'seem': 0.0001711742553920011,
#  'incomprehensible': 0.0001711742553920011,
#  'self': 0.0006846970215680044,
#  'location': 0.0003423485107840022,
#  'intentions': 0.0001711742553920011,
#  'pedestrians': 0.0003423485107840022,
#  'exact': 0.0001711742553920011,
#  'modes': 0.0001711742553920011,
#  'accidents': 0.0001711742553920011,
#  'architectures': 0.0006846970215680044,
#  'limited': 0.0003423485107840022,
#  'simplified': 0.0001711742553920011,
#  'version': 0.0001711742553920011,
#  'really': 0.0003423485107840022,
#  'come': 0.0006846970215680044,
#  'beyond': 0.0003423485107840022,
#  'measure': 0.0001711742553920011,
#  'explanations': 0.0001711742553920011,
#  'occurrences': 0.0001711742553920011,
#  'life': 0.0003423485107840022,
#  'What': 0.0001711742553920011,
#  'straightforward': 0.0006846970215680044,
#  'equivalently': 0.0001711742553920011,
#  'computationally': 0.0001711742553920011,
#  'opposed': 0.0003423485107840022,
#  'gives': 0.0001711742553920011,
#  'classes': 0.0003423485107840022,
#  'models': 0.0010270455323520065,
#  'structuralist': 0.0001711742553920011,
#  'functionalist': 0.0001711742553920011,
#  'structural': 0.0001711742553920011,
#  ...}

# %%
def sentence_scores_calc(word_frequencies,tokenized_sentence):
    sentence_scores = {}
    for sent in tokenized_sentence:
        for word in nltk.word_tokenize(sent.lower()):
            if word in word_frequencies.keys():
                if len(sent.split(' ')) < 30:
                    if sent not in sentence_scores.keys():
                        sentence_scores[sent] = word_frequencies[word]
                    else:
                        sentence_scores[sent] += word_frequencies[word]
    
    return sentence_scores

# %%
sentence_scores = sentence_scores_calc(word_frequencies,sentence_list)
summary_sentences = heapq.nlargest(7, sentence_scores, key=sentence_scores.get)

summary = ' '.join(summary_sentences)
print(summary)
# Out:
# Artificial intelligence (AI), is intelligence demonstrated by machines, unlike the natural intelligence displayed by humans and animals. Musk also funds companies developing artificial intelligence such as DeepMind and Vicarious to "just keep an eye on what's going on with artificial intelligence. A superintelligence, hyperintelligence, or superhuman intelligence is a hypothetical agent that would possess intelligence far surpassing that of the brightest and most gifted human mind. [236] A February 2020 European Union white paper on artificial intelligence advocated for artificial intelligence for economic benefits, including "improving healthcare (e.g. [160][161]
# Many of the problems in this article may also require general intelligence, if machines are to solve the problems as well as people do. [93]
# The overall research goal of artificial intelligence is to create technology that allows computers and machines to function in an intelligent manner. [210] Research in this area includes machine ethics, artificial moral agents, friendly AI and discussion towards building a human rights framework is also in talks.
